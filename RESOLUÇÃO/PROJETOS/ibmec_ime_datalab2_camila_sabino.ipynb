# %% [markdown]
# <a href="https://colab.research.google.com/github/camisabino28/inteligencia_de_mercado_analytics/blob/main/ibmec_ime_datalab2_camila_sabino.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Inteligência de Mercado e Analytics (IBM0115)**

# %%
# Disciplina: Inteligência de Mercado e Analytics (IBM0115)
# DataLab2 (objetivo): Aálise de serie temporal com Python
# Autora: Camila Sabino
# Data: 02/03/2026

# %%
# Definindo vetor para armazenar uma série histórica
count = 25
#print("Minha variável: ", count)

anos_observados = [0] * count
ano_inicial = 2000

# Preenche o vetor que armazena a série histórica
for x in range(count):
  anos_observados[x] = ano_inicial + x

# print(anos_observados)

# Seleciona no vetor os anos desejados
anos_selecionados = [0] * 15


# Preenche o vetor dos anos selecionados
i = 0
for x in anos_observados:
    if x >= 2010:
        anos_selecionados[i] = x
        i += 1


# Preenche o vetor de valores que eu desejo observar na série histórica
valores_selecionados = [7.5, 4.0, 1.9, 3.0, 0.5, -3.5, -3.3, 1.3, 1.8, 1.1, -4.1, 4.6, 3.1, 3.2, 3.5]

# Verifica os valores criados para a série histórica
print(anos_selecionados)
print(valores_selecionados)
# Out:
# [2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024]
# [7.5, 4.0, 1.9, 3.0, 0.5, -3.5, -3.3, 1.3, 1.8, 1.1, -4.1, 4.6, 3.1, 3.2, 3.5]

# %%
# Vizualização dos dados da série histórica
import pandas as pd
